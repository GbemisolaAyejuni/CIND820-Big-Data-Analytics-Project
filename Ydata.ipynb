# %% [markdown]
# <a href="https://colab.research.google.com/github/GbemisolaAyejuni/CIND820-Big-Data-Analytics-Project/blob/main/Ydata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling

# %%
import numpy as np
import pandas as pd
from math import *
import seaborn as sns
import matplotlib.pyplot as plt

# %%
reviews = pd.read_csv('/content/filtered_reviews.zip', sep=',', header=0)
business = pd.read_csv('/content/filtered_businesses.zip', sep=',', header=0)

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(business, title='Exploratory Analysis Report on Business Data')
profile.to_file('Exploratory Analysis Report on Business Data')
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:378: UserWarning: Extension  not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from ydata_profiling import ProfileReport

sampled_df = reviews.sample(frac=0.5, random_state=1)

# Generate the profile report on the sampled data
profile_sampled = ProfileReport(sampled_df, title='Exploratory Analysis Report on Reviews Data (50% Sample)')
profile_sampled.to_file('Exploratory Analysis Report on Reviews Data.html')
#profile = ProfileReport(reviews, title='Exploratory Analysis Report on Reviews Data')
#profile.to_file('Exploratory Analysis Report on Reviews Data.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
